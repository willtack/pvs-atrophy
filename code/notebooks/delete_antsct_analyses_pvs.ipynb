# %%
import flywheel

# Create client
fw = flywheel.Client()

# define containers & files
project = fw.get('5c508d5fc2a4ad002d7628d8')

for ses in project.sessions():
    session = fw.get(ses.id)
    if session.analyses:
        for analysis in session.analyses:
            if 'antsct_2021-05-13_WT_PVS' in analysis.label:
                print("deleting " + analysis.label)
                fw.delete_session_analysis(session.id, analysis.id)
# Out:
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# deleting antsct_2021-05-13_WT_PVS
# ...
