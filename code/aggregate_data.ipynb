# %%
import pandas as pd
import numpy as np
import os

data_dir = "../wscore_data"'

# %%
# load labelset data
label_df = pd.read_excel(os.path.join(local_dir,'Schaefer2018_200Parcels_17Networks_order.xlsx'))
label_names = list(label_df['label_abbrev_name'])
label_full_names = ['17Networks_' + x for x in label_names]
label_full_names[0:10]
# Out:
# ['17Networks_LH_VisCent_ExStr_1',
#  '17Networks_LH_VisCent_ExStr_2',
#  '17Networks_LH_VisCent_Striate_1',
#  '17Networks_LH_VisCent_ExStr_3',
#  '17Networks_LH_VisCent_ExStr_4',
#  '17Networks_LH_VisCent_ExStr_5',
#  '17Networks_LH_VisPeri_ExStrInf_1',
#  '17Networks_LH_VisPeri_ExStrInf_2',
#  '17Networks_LH_VisPeri_ExStrInf_3',
#  '17Networks_LH_VisPeri_StriCal_1']

# %% [markdown]
# ## Create spreadsheet

# %%
# first combine all the dataframes
df_list = []
wscore_df = pd.DataFrame()
for fname in os.listdir(data_dir):
    fpath = os.path.join(data_dir, fname)
    df = pd.read_csv(fpath)
    # add session id as column
    ses_id = fname.split('ses-')[1].split('_')[0]
    df.insert(0, 'SessionID', ses_id)
    # pivot dataframe
    pvtd = df.pivot(index='SessionID', columns='label_full_name', values='w-score')
    # add subject id as column
    sub_id = fname.split('sub-')[1].split('_')[0]
    pvtd.insert(0, 'INDDID', sub_id)
    
    df_list.append(pvtd)

wscore_df = pd.concat(df_list)
wscore_df.head()
# Out:
# label_full_name     INDDID  17Networks_LH_ContA_Cingm_1  \
# SessionID
# 115562x20170309x3T  115562                    -0.694400
# 116707x20190117x3T  116707                     0.954576
# 124288x20190829x3T  124288                     0.118939
# 124868x20190822x3T  124868                    -1.772232
# 119035x20161110x3T  119035                     0.311757
#
# label_full_name     17Networks_LH_ContA_IPS_1  17Networks_LH_ContA_IPS_2  \
# SessionID
# 115562x20170309x3T                   2.321097                   1.294149
# 116707x20190117x3T                   2.575742                   2.154192
# 124288x20190829x3T                  -0.300105                   0.478074
# 124868x20190822x3T                  -0.167389                   0.136095
# 119035x20161110x3T                   0.800142                   1.195299
#
# label_full_name     17Networks_LH_ContA_IPS_3  17Networks_LH_ContA_PFCd_1  \
# SessionID
# 115562x20170309x3T                   0.981595                    2.273557
# 116707x20190117x3T                   1.745228                    1.977333
# 124288x20190829x3T                  -0.321055                   -0.128036
# 124868x20190822x3T                  -1.004691                   -1.113349
# 119035x20161110x3T                   1.297466                    0.318714
#
# label_full_name     17Networks_LH_ContA_PFCl_1  17Networks_LH_ContA_PFCl_2  \
# SessionID
# 115562x20170309x3T                    1.476498                    1.530530
# 116707x20190117x3T                    2.407527                    2.387770
# 124288x20190829x3T                   -0.660108                   -0.273322
# 124868x20190822x3T                   -0.455380                    0.446414
# 119035x20161110x3T                    0.826365                    1.555215
#
# label_full_name     17Networks_LH_ContA_PFCl_3  17Networks_LH_ContA_PFClv_1  \
# SessionID
# 115562x20170309x3T                    1.369574                     2.312892
# 116707x20190117x3T                    2.741372                     2.418698
# 124288x20190829x3T                    0.167206                    -1.672911
# 124868x20190822x3T                   -0.068461                     0.359397
# 119035x20161110x3T                    1.001796                     1.385158
#
# label_full_name     ...  17Networks_RH_VisCent_ExStr_3  \
# SessionID           ...
# 115562x20170309x3T  ...                       1.965991
# 116707x20190117x3T  ...                       2.494180
# 124288x20190829x3T  ...                       0.722583
# 124868x20190822x3T  ...                       0.399515
# 119035x20161110x3T  ...                       1.169241
#
# label_full_name     17Networks_RH_VisCent_ExStr_4  \
# SessionID
# 115562x20170309x3T                       2.492056
# 116707x20190117x3T                       2.851573
# 124288x20190829x3T                       0.760961
# 124868x20190822x3T                      -0.338560
# 119035x20161110x3T                       1.579095
#
# label_full_name     17Networks_RH_VisCent_ExStr_5  \
# SessionID
# 115562x20170309x3T                       1.702256
# 116707x20190117x3T                       2.569641
# 124288x20190829x3T                       0.250942
# 124868x20190822x3T                       0.578593
# 119035x20161110x3T                       1.365458
#
# label_full_name     17Networks_RH_VisCent_Striate_1  \
# SessionID
# 115562x20170309x3T                         0.567938
# 116707x20190117x3T                         1.488172
# 124288x20190829x3T                         0.552577
# 124868x20190822x3T                         0.708675
# 119035x20161110x3T                         1.409013
#
# label_full_name     17Networks_RH_VisPeri_ExStrInf_1  \
# SessionID
# 115562x20170309x3T                          1.523095
# 116707x20190117x3T                          2.234300
# 124288x20190829x3T                          1.486216
# 124868x20190822x3T                          0.580514
# 119035x20161110x3T                          0.556073
#
# label_full_name     17Networks_RH_VisPeri_ExStrInf_2  \
# SessionID
# 115562x20170309x3T                          1.199445
# 116707x20190117x3T                          0.711866
# 124288x20190829x3T                         -0.048384
# 124868x20190822x3T                          0.266053
# 119035x20161110x3T                         -0.328966
#
# label_full_name     17Networks_RH_VisPeri_ExStrSup_1  \
# SessionID
# 115562x20170309x3T                          1.406060
# 116707x20190117x3T                          2.009206
# 124288x20190829x3T                          0.746970
# 124868x20190822x3T                         -0.412246
# 119035x20161110x3T                          0.490455
#
# label_full_name     17Networks_RH_VisPeri_ExStrSup_2  \
# SessionID
# 115562x20170309x3T                          1.764025
# 116707x20190117x3T                          2.298937
# 124288x20190829x3T                          0.872201
# 124868x20190822x3T                         -0.022279
# 119035x20161110x3T                          1.245155
#
# label_full_name     17Networks_RH_VisPeri_ExStrSup_3  \
# SessionID
# 115562x20170309x3T                          1.783238
# 116707x20190117x3T                          2.593222
# 124288x20190829x3T                         -0.060272
# 124868x20190822x3T                         -0.277576
# 119035x20161110x3T                          0.970588
#
# label_full_name     17Networks_RH_VisPeri_StriCal_1
# SessionID
# 115562x20170309x3T                         1.530509
# 116707x20190117x3T                         1.691183
# 124288x20190829x3T                         1.033843
# 124868x20190822x3T                         0.181376
# 119035x20161110x3T                         1.396526
#
# [5 rows x 201 columns]

# %%
wscore_df = wscore_df.reindex(['INDDID'] + label_full_names, axis=1)

# %%
wscore_df.head()
# Out:
# label_full_name     INDDID  17Networks_LH_VisCent_ExStr_1  \
# SessionID
# 115562x20170309x3T  115562                       1.937467
# 116707x20190117x3T  116707                       1.537478
# 124288x20190829x3T  124288                       1.116862
# 124868x20190822x3T  124868                       0.256561
# 119035x20161110x3T  119035                       1.040535
#
# label_full_name     17Networks_LH_VisCent_ExStr_2  \
# SessionID
# 115562x20170309x3T                       0.865290
# 116707x20190117x3T                       1.356918
# 124288x20190829x3T                       1.068120
# 124868x20190822x3T                       0.252578
# 119035x20161110x3T                       0.926120
#
# label_full_name     17Networks_LH_VisCent_Striate_1  \
# SessionID
# 115562x20170309x3T                         0.304432
# 116707x20190117x3T                        -0.205439
# 124288x20190829x3T                         0.906187
# 124868x20190822x3T                         0.084412
# 119035x20161110x3T                         0.789567
#
# label_full_name     17Networks_LH_VisCent_ExStr_3  \
# SessionID
# 115562x20170309x3T                       1.894185
# 116707x20190117x3T                       2.195686
# 124288x20190829x3T                       0.229293
# 124868x20190822x3T                       0.782695
# 119035x20161110x3T                       1.440901
#
# label_full_name     17Networks_LH_VisCent_ExStr_4  \
# SessionID
# 115562x20170309x3T                       2.757598
# 116707x20190117x3T                       2.415308
# 124288x20190829x3T                       0.771403
# 124868x20190822x3T                      -0.130224
# 119035x20161110x3T                       1.464325
#
# label_full_name     17Networks_LH_VisCent_ExStr_5  \
# SessionID
# 115562x20170309x3T                       2.196862
# 116707x20190117x3T                       2.577049
# 124288x20190829x3T                       0.559947
# 124868x20190822x3T                       0.082596
# 119035x20161110x3T                       1.211705
#
# label_full_name     17Networks_LH_VisPeri_ExStrInf_1  \
# SessionID
# 115562x20170309x3T                          2.073014
# 116707x20190117x3T                          2.282898
# 124288x20190829x3T                          0.999771
# 124868x20190822x3T                          0.541404
# 119035x20161110x3T                          1.115633
#
# label_full_name     17Networks_LH_VisPeri_ExStrInf_2  \
# SessionID
# 115562x20170309x3T                          1.088571
# 116707x20190117x3T                          1.579406
# 124288x20190829x3T                          0.995084
# 124868x20190822x3T                          0.379766
# 119035x20161110x3T                          0.797385
#
# label_full_name     17Networks_LH_VisPeri_ExStrInf_3  ...  \
# SessionID                                             ...
# 115562x20170309x3T                          2.403711  ...
# 116707x20190117x3T                          1.198403  ...
# 124288x20190829x3T                          0.018267  ...
# 124868x20190822x3T                         -0.915315  ...
# 119035x20161110x3T                         -1.257075  ...
#
# label_full_name     17Networks_RH_DefaultB_AntTemp_1  \
# SessionID
# 115562x20170309x3T                          1.827341
# 116707x20190117x3T                          1.598266
# 124288x20190829x3T                          0.294485
# 124868x20190822x3T                         -0.084277
# 119035x20161110x3T                         -0.051632
#
# label_full_name     17Networks_RH_DefaultB_PFCd_1  \
# SessionID
# 115562x20170309x3T                       1.307841
# 116707x20190117x3T                       2.386526
# 124288x20190829x3T                       0.023493
# 124868x20190822x3T                      -0.778188
# 119035x20161110x3T                       1.253653
#
# label_full_name     17Networks_RH_DefaultB_PFCv_1  \
# SessionID
# 115562x20170309x3T                       2.623699
# 116707x20190117x3T                       2.787714
# 124288x20190829x3T                       0.213185
# 124868x20190822x3T                       0.854505
# 119035x20161110x3T                       0.529592
#
# label_full_name     17Networks_RH_DefaultC_IPL_1  \
# SessionID
# 115562x20170309x3T                      2.756166
# 116707x20190117x3T                      2.394199
# 124288x20190829x3T                     -0.309003
# 124868x20190822x3T                      0.008148
# 119035x20161110x3T                      1.171455
#
# label_full_name     17Networks_RH_DefaultC_Rsp_1  \
# SessionID
# 115562x20170309x3T                      1.201103
# 116707x20190117x3T                      1.925642
# 124288x20190829x3T                     -0.482059
# 124868x20190822x3T                     -0.097580
# 119035x20161110x3T                      1.035902
#
# label_full_name     17Networks_RH_DefaultC_PHC_1  17Networks_RH_TempPar_1  \
# SessionID
# 115562x20170309x3T                     -0.057126                 2.297526
# 116707x20190117x3T                      0.751033                 1.220740
# 124288x20190829x3T                     -0.050471                 0.807194
# 124868x20190822x3T                     -0.286652                -0.167386
# 119035x20161110x3T                     -0.197012                -0.266342
#
# label_full_name     17Networks_RH_TempPar_2  17Networks_RH_TempPar_3  \
# SessionID
# 115562x20170309x3T                 1.692659                 2.801574
# 116707x20190117x3T                 2.141935                 2.743767
# 124288x20190829x3T                -0.119892                 0.624068
# 124868x20190822x3T                 0.398563                -0.043057
# 119035x20161110x3T                 0.293893                 1.326264
#
# label_full_name     17Networks_RH_TempPar_4
# SessionID
# 115562x20170309x3T                 2.595450
# 116707x20190117x3T                 2.464402
# 124288x20190829x3T                 0.022494
# 124868x20190822x3T                -0.413330
# 119035x20161110x3T                 0.904422
#
# [5 rows x 201 columns]

# %%
# now add in ClinicalRead and AgeAtMRI from original spreadsheet
orig_spreadsheet = os.path.join(local_dir, 'PVS_subjects.xlsx')
orig_df = pd.read_excel(orig_spreadsheet)
orig_df.head()

# go through original df and get Age and Read from each subject, then add those to a dictionary of sid: {age, read}
d = {}
for row in orig_df.itertuples(index=False):
    d[row.INDDID] = [row.AgeatMRI, row.Clinical_Read]

d[122975]
# Out:
# [72, 'Negative']

# %%
for k in d.keys():
    # k is INDDID; assign k's Age and Read to respective columns in main dataframe
    wscore_df.loc[(wscore_df.INDDID==str(k)),'AgeAtMRI']=d[k][0]
    wscore_df.loc[(wscore_df.INDDID==str(k)),'Clinical_Read']=d[k][1]
    
    # shift columns to first position
    age = wscore_df.pop('AgeAtMRI')
    read = wscore_df.pop('Clinical_Read')
    wscore_df.insert(1, 'AgeAtMRI', age)
    wscore_df.insert(2, 'Clinical_Read', read)
    
wscore_df.to_csv(os.path.join(local_dir, 'wscore_data.csv'))
wscore_df.head()
# Out:
# label_full_name     INDDID  AgeAtMRI Clinical_Read  \
# SessionID
# 115562x20170309x3T  115562      89.0      Positive
# 116707x20190117x3T  116707      86.0      Positive
# 124288x20190829x3T  124288      67.0      Negative
# 124868x20190822x3T  124868      65.0      Negative
# 119035x20161110x3T  119035      75.0      Negative
#
# label_full_name     17Networks_LH_VisCent_ExStr_1  \
# SessionID
# 115562x20170309x3T                       1.937467
# 116707x20190117x3T                       1.537478
# 124288x20190829x3T                       1.116862
# 124868x20190822x3T                       0.256561
# 119035x20161110x3T                       1.040535
#
# label_full_name     17Networks_LH_VisCent_ExStr_2  \
# SessionID
# 115562x20170309x3T                       0.865290
# 116707x20190117x3T                       1.356918
# 124288x20190829x3T                       1.068120
# 124868x20190822x3T                       0.252578
# 119035x20161110x3T                       0.926120
#
# label_full_name     17Networks_LH_VisCent_Striate_1  \
# SessionID
# 115562x20170309x3T                         0.304432
# 116707x20190117x3T                        -0.205439
# 124288x20190829x3T                         0.906187
# 124868x20190822x3T                         0.084412
# 119035x20161110x3T                         0.789567
#
# label_full_name     17Networks_LH_VisCent_ExStr_3  \
# SessionID
# 115562x20170309x3T                       1.894185
# 116707x20190117x3T                       2.195686
# 124288x20190829x3T                       0.229293
# 124868x20190822x3T                       0.782695
# 119035x20161110x3T                       1.440901
#
# label_full_name     17Networks_LH_VisCent_ExStr_4  \
# SessionID
# 115562x20170309x3T                       2.757598
# 116707x20190117x3T                       2.415308
# 124288x20190829x3T                       0.771403
# 124868x20190822x3T                      -0.130224
# 119035x20161110x3T                       1.464325
#
# label_full_name     17Networks_LH_VisCent_ExStr_5  \
# SessionID
# 115562x20170309x3T                       2.196862
# 116707x20190117x3T                       2.577049
# 124288x20190829x3T                       0.559947
# 124868x20190822x3T                       0.082596
# 119035x20161110x3T                       1.211705
#
# label_full_name     17Networks_LH_VisPeri_ExStrInf_1  ...  \
# SessionID                                             ...
# 115562x20170309x3T                          2.073014  ...
# 116707x20190117x3T                          2.282898  ...
# 124288x20190829x3T                          0.999771  ...
# 124868x20190822x3T                          0.541404  ...
# 119035x20161110x3T                          1.115633  ...
#
# label_full_name     17Networks_RH_DefaultB_AntTemp_1  \
# SessionID
# 115562x20170309x3T                          1.827341
# 116707x20190117x3T                          1.598266
# 124288x20190829x3T                          0.294485
# 124868x20190822x3T                         -0.084277
# 119035x20161110x3T                         -0.051632
#
# label_full_name     17Networks_RH_DefaultB_PFCd_1  \
# SessionID
# 115562x20170309x3T                       1.307841
# 116707x20190117x3T                       2.386526
# 124288x20190829x3T                       0.023493
# 124868x20190822x3T                      -0.778188
# 119035x20161110x3T                       1.253653
#
# label_full_name     17Networks_RH_DefaultB_PFCv_1  \
# SessionID
# 115562x20170309x3T                       2.623699
# 116707x20190117x3T                       2.787714
# 124288x20190829x3T                       0.213185
# 124868x20190822x3T                       0.854505
# 119035x20161110x3T                       0.529592
#
# label_full_name     17Networks_RH_DefaultC_IPL_1  \
# SessionID
# 115562x20170309x3T                      2.756166
# 116707x20190117x3T                      2.394199
# 124288x20190829x3T                     -0.309003
# 124868x20190822x3T                      0.008148
# 119035x20161110x3T                      1.171455
#
# label_full_name     17Networks_RH_DefaultC_Rsp_1  \
# SessionID
# 115562x20170309x3T                      1.201103
# 116707x20190117x3T                      1.925642
# 124288x20190829x3T                     -0.482059
# 124868x20190822x3T                     -0.097580
# 119035x20161110x3T                      1.035902
#
# label_full_name     17Networks_RH_DefaultC_PHC_1  17Networks_RH_TempPar_1  \
# SessionID
# 115562x20170309x3T                     -0.057126                 2.297526
# 116707x20190117x3T                      0.751033                 1.220740
# 124288x20190829x3T                     -0.050471                 0.807194
# 124868x20190822x3T                     -0.286652                -0.167386
# 119035x20161110x3T                     -0.197012                -0.266342
#
# label_full_name     17Networks_RH_TempPar_2  17Networks_RH_TempPar_3  \
# SessionID
# 115562x20170309x3T                 1.692659                 2.801574
# 116707x20190117x3T                 2.141935                 2.743767
# 124288x20190829x3T                -0.119892                 0.624068
# 124868x20190822x3T                 0.398563                -0.043057
# 119035x20161110x3T                 0.293893                 1.326264
#
# label_full_name     17Networks_RH_TempPar_4
# SessionID
# 115562x20170309x3T                 2.595450
# 116707x20190117x3T                 2.464402
# 124288x20190829x3T                 0.022494
# 124868x20190822x3T                -0.413330
# 119035x20161110x3T                 0.904422
#
# [5 rows x 203 columns]

# %% [markdown]
# ## Reviewing quantities

# %%
#ax = sns.boxplot(x="Clinical_Read", y="17Networks_LH_DefaultB_Temp_1", data=pvs_df)

# %%
# break down INDDID list into amyloid positive/negative patients
pos_inddid = list(wscore_df[wscore_df['Clinical_Read']=='Positive']['INDDID'])
neg_inddid = list(wscore_df[wscore_df['Clinical_Read']=='Negative']['INDDID'])

# expect some INDDID duplicates because of longitudinal sessions
print(len(pos_inddid))
print(len(neg_inddid))
print(len(set(pos_inddid)))
print(len(set(neg_inddid)))
# Out:
# 82
# 93
# 60
# 61

# %%
# Code snippet for getting scores from a particular region.
pos_temp_wscores = list(wscore_df[wscore_df['Clinical_Read']=='Positive']['17Networks_LH_DefaultB_Temp_2'])
neg_temp_wscores = list(wscore_df[wscore_df['Clinical_Read']=='Negative']['17Networks_LH_DefaultB_Temp_2'])
# import scipy
# from scipy import stats
# scipy.stats.ttest_ind(pos_temp_wscores, neg_temp_wscores)

# Should all be unique
print(len(pos_temp_wscores))
print(len(set(pos_temp_wscores)))
print(len(neg_temp_wscores))
print(len(set(neg_temp_wscores)))
# Out:
# 82
# 82
# 93
# 93

# %% [markdown]
# ## Weight w-scores by ROI volume

# %% [markdown]
# ~~Manually copy weights from /home/will/Projects/healthy-t1-dataset/labels/Schaefer2018_200Parcels_17Networks_order.xlsx to PVS_data.csv.~~

# %%
vol_list = list(label_df['volume'])
vol_list[0:10]
# Out:
# [9225, 6346, 7116, 6267, 6246, 6376, 4634, 4835, 1239, 8181]

# %%
# go through every column of pvs_data (i.e. every ROI) and multiply by corresponding volume
# gives a tuple of column name and series for each column in the dataframe
w_wscore_df = wscore_df.copy()
for (column_name, column_data) in wscore_df.items():
    if '17Networks' in column_name:
        abbrev_name = column_name.split('17Networks_')[1]
        volume = label_df.loc[(label_df.label_abbrev_name==abbrev_name),'volume']
        
        wscores = np.array([float(x) for x in column_data.values])
        weighted_wscores = np.multiply(wscores, int(volume))
        #print("{} | {} | {} | {}".format(column_data[0], abbrev_name, int(volume), weighted_wscores[0])
        
        # assign weighted values to new column
        new_col_name = 'weighted_' + column_name
        w_wscore_df[new_col_name] = weighted_wscores

# %%
# calculate weighted averages for all regions, frontal regions, etc. and insert into dataframe
wa_total_list = []
wa_pfron_list = []
total_median_list = []
pfron_median_list = []
for index, row in w_wscore_df.iterrows():

    sum_weights = np.sum(label_df['volume']) 
    weighted_cols = [col for col in row.index if col.startswith('weighted')]

    # calculate weighted average for all 200 regions
    weighted_wscores = row[weighted_cols]
    sum_weighted = np.sum(weighted_wscores)
    wa_total = np.divide(sum_weighted, sum_weights)
    
    # calculate weighted average for frontal regions
    pfron_cols = [col for col in weighted_cols if 'PFC' in col or 'OFC' in col]
    pfron_weighted_wscores = row[pfron_cols]
    pfron_weighted = np.sum(pfron_weighted_wscores)
    wa_pfron = np.divide(pfron_weighted, sum_weights)
    
    # calculate median for all 200 regions
    total_median = np.median(weighted_wscores)
    total_median_list.append(total_median)
    pfron_median = np.median(pfron_weighted_wscores)
    pfron_median_list.append(pfron_median)
    
    wa_total_list.append(wa_total)
    wa_pfron_list.append(wa_pfron)
    

# assign weighted averages to new column(s)
w_wscore_df.insert(3, 'prefrontal_median', pfron_median_list, allow_duplicates=False)
w_wscore_df.insert(3, 'allROIs_median', total_median_list, allow_duplicates=False)
w_wscore_df.insert(3, 'pfron_weighted_average', wa_pfron_list, allow_duplicates=False)
w_wscore_df.insert(3, 'allROIs_weighted_average', wa_total_list, allow_duplicates=False)

w_wscore_df.to_csv(os.path.join(local_dir, 'weighted_wscore_data.csv'))

# %%
w_wscore_df.head()
# Out:
# label_full_name     INDDID  AgeAtMRI Clinical_Read  allROIs_weighted_average  \
# SessionID
# 115562x20170309x3T  115562      89.0      Positive                  1.895779
# 116707x20190117x3T  116707      86.0      Positive                  2.156533
# 124288x20190829x3T  124288      67.0      Negative                  0.253250
# 124868x20190822x3T  124868      65.0      Negative                 -0.108497
# 119035x20161110x3T  119035      75.0      Negative                  0.739024
#
# label_full_name     pfron_weighted_average  allROIs_median  prefrontal_median  \
# SessionID
# 115562x20170309x3T                0.541931     9784.121796       11426.068889
# 116707x20190117x3T                0.691856    11281.895896       16822.447572
# 124288x20190829x3T                0.025977     1062.204982         529.805442
# 124868x20190822x3T               -0.026737     -380.114503        -290.581213
# 119035x20161110x3T                0.259608     3918.627001        6250.654416
#
# label_full_name     17Networks_LH_VisCent_ExStr_1  \
# SessionID
# 115562x20170309x3T                       1.937467
# 116707x20190117x3T                       1.537478
# 124288x20190829x3T                       1.116862
# 124868x20190822x3T                       0.256561
# 119035x20161110x3T                       1.040535
#
# label_full_name     17Networks_LH_VisCent_ExStr_2  \
# SessionID
# 115562x20170309x3T                       0.865290
# 116707x20190117x3T                       1.356918
# 124288x20190829x3T                       1.068120
# 124868x20190822x3T                       0.252578
# 119035x20161110x3T                       0.926120
#
# label_full_name     17Networks_LH_VisCent_Striate_1  ...  \
# SessionID                                            ...
# 115562x20170309x3T                         0.304432  ...
# 116707x20190117x3T                        -0.205439  ...
# 124288x20190829x3T                         0.906187  ...
# 124868x20190822x3T                         0.084412  ...
# 119035x20161110x3T                         0.789567  ...
#
# label_full_name     weighted_17Networks_RH_DefaultB_AntTemp_1  \
# SessionID
# 115562x20170309x3T                               16965.030062
# 116707x20190117x3T                               14838.298033
# 124288x20190829x3T                                2733.994633
# 124868x20190822x3T                                -782.423745
# 119035x20161110x3T                                -479.352709
#
# label_full_name     weighted_17Networks_RH_DefaultB_PFCd_1  \
# SessionID
# 115562x20170309x3T                            10074.302403
# 116707x20190117x3T                            18383.411784
# 124288x20190829x3T                              180.967572
# 124868x20190822x3T                            -5994.380009
# 119035x20161110x3T                             9656.888727
#
# label_full_name     weighted_17Networks_RH_DefaultB_PFCv_1  \
# SessionID
# 115562x20170309x3T                            24568.316148
# 116707x20190117x3T                            26104.149820
# 124288x20190829x3T                             1996.266629
# 124868x20190822x3T                             8001.589059
# 119035x20161110x3T                             4959.100231
#
# label_full_name     weighted_17Networks_RH_DefaultC_IPL_1  \
# SessionID
# 115562x20170309x3T                           18088.715474
# 116707x20190117x3T                           15713.126473
# 124288x20190829x3T                           -2027.984322
# 124868x20190822x3T                              53.475662
# 119035x20161110x3T                            7688.259230
#
# label_full_name     weighted_17Networks_RH_DefaultC_Rsp_1  \
# SessionID
# 115562x20170309x3T                            4850.051989
# 116707x20190117x3T                            7775.743461
# 124288x20190829x3T                           -1946.555105
# 124868x20190822x3T                            -394.028740
# 119035x20161110x3T                            4182.973979
#
# label_full_name     weighted_17Networks_RH_DefaultC_PHC_1  \
# SessionID
# 115562x20170309x3T                            -319.905954
# 116707x20190117x3T                            4205.786703
# 124288x20190829x3T                            -282.639022
# 124868x20190822x3T                           -1605.253393
# 119035x20161110x3T                           -1103.268076
#
# label_full_name     weighted_17Networks_RH_TempPar_1  \
# SessionID
# 115562x20170309x3T                      14361.835414
# 116707x20190117x3T                       7630.842623
# 124288x20190829x3T                       5045.767012
# 124868x20190822x3T                      -1046.331150
# 119035x20161110x3T                      -1664.903651
#
# label_full_name     weighted_17Networks_RH_TempPar_2  \
# SessionID
# 115562x20170309x3T                       6613.219582
# 116707x20190117x3T                       8368.540131
# 124288x20190829x3T                       -468.416483
# 124868x20190822x3T                       1557.185100
# 119035x20161110x3T                       1148.240208
#
# label_full_name     weighted_17Networks_RH_TempPar_3  \
# SessionID
# 115562x20170309x3T                      11239.913677
# 116707x20190117x3T                      11007.995171
# 124288x20190829x3T                       2503.760738
# 124868x20190822x3T                       -172.744248
# 119035x20161110x3T                       5320.971005
#
# label_full_name     weighted_17Networks_RH_TempPar_4
# SessionID
# 115562x20170309x3T                       8837.507281
# 116707x20190117x3T                       8391.289830
# 124288x20190829x3T                         76.592486
# 124868x20190822x3T                      -1407.389392
# 119035x20161110x3T                       3079.557580
#
# [5 rows x 407 columns]
